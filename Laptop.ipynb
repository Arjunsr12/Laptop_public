# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjunsr12/Laptop_public/blob/main/Laptop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/ADVERK /Datasets/laptop_data.csv")
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
df=df.iloc[:,1:]
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df['Ram']
# Out:
# 0        8GB
# 1        8GB
# 2        8GB
# 3       16GB
# 4        8GB
#         ...
# 1298     4GB
# 1299    16GB
# 1300     2GB
# 1301     6GB
# 1302     4GB
# Name: Ram, Length: 1303, dtype: object

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')

# %%
print(df['Ram'])
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype("float")
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: Ram, Length: 1303, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 112.1+ KB

# %%
df.sample(5)
# Out:
#       Company  TypeName  Inches   ScreenResolution  \
# 159   Toshiba  Notebook    15.6           1366x768
# 317    Lenovo  Notebook    13.3           1366x768
# 1280       HP  Notebook    15.6  Full HD 1920x1080
# 593   Samsung  Notebook    15.6  Full HD 1920x1080
# 1041     Vero  Notebook    14.0           1366x768
#
#                                        Cpu  Ram                Memory  \
# 159             Intel Core i3 6006U 2.2GHz    4             500GB HDD
# 317   Intel Celeron Dual Core 3855U 1.6GHz    4    16GB Flash Storage
# 1280             AMD A9-Series 9410 2.9GHz    6          1.0TB Hybrid
# 593            Intel Core i7 7700HQ 2.8GHz   16  128GB SSD +  1TB HDD
# 1041           Intel Atom X5-Z8350 1.44GHz    2    32GB Flash Storage
#
#                           Gpu       OpSys  Weight       Price
# 159     Intel HD Graphics 520  Windows 10    2.10  23816.1600
# 317     Intel HD Graphics 510   Chrome OS    1.45  24503.4720
# 1280       AMD Radeon R7 M440  Windows 10    2.04  29303.4672
# 593   Nvidia GeForce GTX 1050  Windows 10    2.50  90522.7200
# 1041    Intel HD Graphics 400  Windows 10    1.45  11231.4240

# %%
sns.distplot(df['Price'])
plt.show()
# Out:
# <ipython-input-270-199b2c49b713>:1: UserWarning:
#
# `displot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.displot(df['Price'])

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
sns.distplot(df['Inches'])
# Out:
# <ipython-input-276-51888cb550e6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.barplot(x=df['Inches'],y=df['Price'])
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-17 10:48:55.741 INFO    matplotlib.category: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-17 10:48:55.768 INFO    matplotlib.category: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[-1]).astype('int')

# %%
df.sample(5)
# Out:
#       Company   TypeName  Inches   ScreenResolution  \
# 862   Toshiba   Notebook    13.3  Full HD 1920x1080
# 875      Dell  Ultrabook    12.5  Full HD 1920x1080
# 1041     Vero   Notebook    14.0           1366x768
# 39         HP   Notebook    15.6  Full HD 1920x1080
# 435      Asus     Gaming    17.3  Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 862    Intel Core i5 7200U 2.5GHz    4             128GB SSD
# 875    Intel Core i7 7600U 2.8GHz    8             256GB SSD
# 1041  Intel Atom X5-Z8350 1.44GHz    2    32GB Flash Storage
# 39     Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 435         AMD Ryzen 1600 3.2GHz    8  256GB SSD +  1TB HDD
#
#                         Gpu       OpSys  Weight      Price  X_res  Y_res
# 862   Intel HD Graphics 620  Windows 10    1.05  68464.800   1920   1080
# 875   Intel HD Graphics 620  Windows 10    1.60  90043.200   1920   1080
# 1041  Intel HD Graphics 400  Windows 10    1.45  11231.424   1366    768
# 39    Nvidia GeForce 930MX   Windows 10    2.10  46833.120   1920   1080
# 435       AMD Radeon RX 580  Windows 10    3.20  90309.600   1920   1080

# %%
df['IPS']=df['ScreenResolution'].apply(lambda b:1 if "IPS" in b else 0)
df['Touchscreen']=df['ScreenResolution'].apply(lambda b:1 if "Touchscreen" in b else 0)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches   ScreenResolution  \
# 865       HP  Notebook    15.6  Full HD 1920x1080
# 333   Lenovo  Notebook    15.6  Full HD 1920x1080
# 1222      HP  Notebook    15.6  Full HD 1920x1080
# 213   Lenovo  Notebook    15.6  Full HD 1920x1080
# 805       HP   Netbook    12.5           1366x768
#
#                               Cpu  Ram     Memory                    Gpu  \
# 865    Intel Core i5 6200U 2.3GHz    4  500GB HDD  Intel HD Graphics 520
# 333      Intel Core i3 6006U 2GHz    4    1TB HDD  Intel HD Graphics 520
# 1222  AMD A12-Series 9720P 2.7GHz    6    1TB HDD         AMD Radeon 530
# 213    Intel Core i5 7200U 2.5GHz    8  256GB SSD  Intel HD Graphics 620
# 805    Intel Core i5 7300U 2.6GHz    8  256GB SSD  Intel HD Graphics 620
#
#            OpSys  Weight     Price  X_res  Y_res  IPS  Touchscreen
# 865   Windows 10    2.07  48484.80   1920   1080    0            0
# 333   Windows 10    1.85  23922.72   1920   1080    0            0
# 1222  Windows 10    2.10  28185.12   1920   1080    0            0
# 213        No OS    2.20  29250.72   1920   1080    0            0
# 805   Windows 10    1.26  74005.92   1366    768    0            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  X_res             1303 non-null   int64
#  12  Y_res             1303 non-null   int64
#  13  IPS               1303 non-null   int64
#  14  Touchscreen       1303 non-null   int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 152.8+ KB

# %%
df=df.drop(columns=['ScreenResolution'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Inches       1303 non-null   float64
#  3   Cpu          1303 non-null   object
#  4   Ram          1303 non-null   int64
#  5   Memory       1303 non-null   object
#  6   Gpu          1303 non-null   object
#  7   OpSys        1303 non-null   object
#  8   Weight       1303 non-null   float64
#  9   Price        1303 non-null   float64
#  10  X_res        1303 non-null   int64
#  11  Y_res        1303 non-null   int64
#  12  IPS          1303 non-null   int64
#  13  Touchscreen  1303 non-null   int64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 142.6+ KB

# %%
df.corr(numeric_only=True)
#corr=corelation
# Out:
#                Inches       Ram    Weight     Price     X_res     Y_res  \
# Inches       1.000000  0.237993  0.827631  0.068197 -0.071245 -0.095404
# Ram          0.237993  1.000000  0.383874  0.743007  0.433121  0.424437
# Weight       0.827631  0.383874  1.000000  0.210370 -0.032880 -0.053846
# Price        0.068197  0.743007  0.210370  1.000000  0.556529  0.552809
# X_res       -0.071245  0.433121 -0.032880  0.556529  1.000000  0.994219
# Y_res       -0.095404  0.424437 -0.053846  0.552809  0.994219  1.000000
# IPS         -0.114804  0.206623  0.016967  0.252208  0.281457  0.289030
# Touchscreen -0.361735  0.116984 -0.294620  0.191226  0.351066  0.357930
#
#                   IPS  Touchscreen
# Inches      -0.114804    -0.361735
# Ram          0.206623     0.116984
# Weight       0.016967    -0.294620
# Price        0.252208     0.191226
# X_res        0.281457     0.351066
# Y_res        0.289030     0.357930
# IPS          1.000000     0.150512
# Touchscreen  0.150512     1.000000

# %%
df['PPI']=round(((df['X_res']**2)+(df['Y_res']**2)**0.5)/df['Inches'])

# %%
df.sample(5)
# Out:
#       Company  TypeName  Inches                                   Cpu  Ram  \
# 1268       HP   Netbook    11.6  Intel Celeron Dual Core N3060 1.6GHz    2
# 149      Acer  Notebook    15.6              Intel Core i3 6006U 2GHz    4
# 531   Toshiba  Notebook    15.6            Intel Core i5 7200U 2.5GHz    8
# 416      Dell  Notebook    13.3              Intel Core i3 6006U 2GHz    4
# 315      Dell  Notebook    15.6            Intel Core i5 8250U 1.6GHz    8
#
#                     Memory                    Gpu       OpSys  Weight  \
# 1268    32GB Flash Storage  Intel HD Graphics 400  Windows 10    1.17
# 149                1TB HDD  Intel HD Graphics 520  Windows 10    2.10
# 531              500GB HDD  Intel HD Graphics 620  Windows 10    2.00
# 416              128GB SSD  Intel HD Graphics 520  Windows 10    1.65
# 315   128GB SSD +  1TB HDD         AMD Radeon 530  Windows 10    2.33
#
#          Price  X_res  Y_res  IPS  Touchscreen       PPI
# 1268  11135.52   1366    768    0            0  160924.0
# 149   23816.16   1366    768    0            0  119662.0
# 531   45820.80   1920   1080    1            0  236377.0
# 416   36709.92   1366    768    0            0  140355.0
# 315   44968.32   1920   1080    0            0  236377.0

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# X_res          0.556529
# Y_res          0.552809
# IPS            0.252208
# Touchscreen    0.191226
# PPI            0.480376
# Name: Price, dtype: float64

# %%
df=df.drop(columns=['X_res','Y_res','Inches'])

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# IPS            0.252208
# Touchscreen    0.191226
# PPI            0.480376
# Name: Price, dtype: float64

# %%
sns.distplot(df['PPI'])
plt.show()
# Out:
# <ipython-input-291-b69f1c6db184>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PPI'])

# %%
sns.scatterplot(x=df['PPI'],y=df['Price'])
plt.show()

# %%
df['IPS'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x=df["IPS"],y=df['Price'])
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-17 10:48:58.552 INFO    matplotlib.category: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-17 10:48:58.578 INFO    matplotlib.category: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
df['Touchscreen'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-17 10:48:59.194 INFO    matplotlib.category: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-17 10:48:59.217 INFO    matplotlib.category: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
sns.distplot(df['PPI'])
# Out:
# <ipython-input-297-fc82d774d6d7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PPI'])
# <Axes: xlabel='PPI', ylabel='Density'>

# %%
df['Cpu']=df['Cpu'].apply(lambda a:' '.join(a.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# Intel Atom X5-Z8350           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# Intel Xeon E3-1505M           2
# AMD E-Series 7110             2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# AMD Ryzen 1600                1
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# AMD FX 9830P                  1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom Z8350              1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000e            1
# Samsung Cortex A72&A53        1
# AMD E-Series 9000             1
# AMD E-Series 6110             1
# Name: count, dtype: int64

# %%
def fetch_processor(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  elif text=='Intel Celeron Dual':
    return 'Intel Celeron Dual Core'
  else:
    if text.split()[0]=='Intel':
      return 'Other Intel Processor'
    else:
      return 'AMD Processor'

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7              527
# Intel Core i5              423
# Intel Core i3              136
# Intel Celeron Dual Core     80
# Other Intel Processor       74
# AMD Processor               63
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x=df['Cpu'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.sample(5)
# Out:
#     Company  TypeName            Cpu  Ram                Memory  \
# 418    Dell  Notebook  Intel Core i5    8               1TB HDD
# 381  Lenovo  Notebook  Intel Core i3    4             128GB SSD
# 589    Asus    Gaming  Intel Core i5    8  128GB SSD +  1TB HDD
# 153     MSI    Gaming  Intel Core i7   16  256GB SSD +  1TB HDD
# 326    Acer  Notebook  Intel Core i5    6               1TB HDD
#
#                          Gpu       OpSys  Weight       Price  IPS  \
# 418    Intel HD Graphics 620  Windows 10    2.14   28768.536    0
# 381    Intel HD Graphics 520       No OS    1.85   21498.480    0
# 589  Nvidia GeForce GTX 1060  Windows 10    2.73   94305.600    1
# 153  Nvidia GeForce GTX 1060  Windows 10    2.80  100699.200    0
# 326    Intel HD Graphics 620  Windows 10    2.23   29250.720    0
#
#      Touchscreen       PPI
# 418            0  119662.0
# 381            0  236377.0
# 589            0  213149.0
# 153            0  213149.0
# 326            0  119662.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Cpu          1303 non-null   object
#  3   Ram          1303 non-null   int64
#  4   Memory       1303 non-null   object
#  5   Gpu          1303 non-null   object
#  6   OpSys        1303 non-null   object
#  7   Weight       1303 non-null   float64
#  8   Price        1303 non-null   float64
#  9   IPS          1303 non-null   int64
#  10  Touchscreen  1303 non-null   int64
#  11  PPI          1303 non-null   float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 122.3+ KB

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Cpu          1303 non-null   object
#  3   Ram          1303 non-null   int64
#  4   Memory       1303 non-null   object
#  5   Gpu          1303 non-null   object
#  6   OpSys        1303 non-null   object
#  7   Weight       1303 non-null   float64
#  8   Price        1303 non-null   float64
#  9   IPS          1303 non-null   int64
#  10  Touchscreen  1303 non-null   int64
#  11  PPI          1303 non-null   float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 122.3+ KB

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.show()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-17 10:49:01.111 INFO    matplotlib.category: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-10-17 10:49:01.129 INFO    matplotlib.category: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
a='Intel HD Graphics 620 '
a.split()
# Out:
# ['Intel', 'HD', 'Graphics', '620']

# %%
a.split()[0]
# Out:
# 'Intel'

# %%
df['Gpu']=df['Gpu'].apply(lambda a:a.split()[0])

# %%
df=df[df['Gpu']!='ARM']

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
sns.barplot(x=df['Gpu'],y=df['Price'])
# Out:
# <Axes: xlabel='Gpu', ylabel='Price'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Cpu          1302 non-null   object
#  3   Ram          1302 non-null   int64
#  4   Memory       1302 non-null   object
#  5   Gpu          1302 non-null   object
#  6   OpSys        1302 non-null   object
#  7   Weight       1302 non-null   float64
#  8   Price        1302 non-null   float64
#  9   IPS          1302 non-null   int64
#  10  Touchscreen  1302 non-null   int64
#  11  PPI          1302 non-null   float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 132.2+ KB

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def opsys(text):
  if text=='Windows 10' or text=='Windows 7' or text=='Windows 10 S' or text=='Windows':
    return 'Windows'
  elif text=='macOS' or text=='Mac OS X' or text=='Mac OS':
    return 'Mac'
  elif text=='Linux':
    return 'Linux'
  else:
    return 'Chrome OS/Andriod/NoOS'

# %%
df['OpSys']=df['OpSys'].apply(opsys)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows                   1125
# Chrome OS/Andriod/NoOS      94
# Linux                       62
# Mac                         21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Weight'].describe()
# Out:
# count    1302.000000
# mean        2.039416
# std         0.665274
# min         0.690000
# 25%         1.500000
# 50%         2.040000
# 75%         2.300000
# max         4.700000
# Name: Weight, dtype: float64

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# IPS            0.253320
# Touchscreen    0.192917
# PPI            0.481351
# Name: Price, dtype: float64

# %%
sns.distplot(df['Weight'])
# Out:
# <ipython-input-326-05ee4c8848be>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df['Memory']
# Out:
# 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 3                 512GB SSD
# 4                 256GB SSD
#                ...
# 1298              128GB SSD
# 1299              512GB SSD
# 1300     64GB Flash Storage
# 1301                1TB HDD
# 1302              500GB HDD
# Name: Memory, Length: 1302, dtype: object

# %%
fdf=df.drop(columns=['Memory'],inplace=True)

# %%
df
# Out:
#      Company            TypeName                      Cpu  Ram    Gpu  \
# 0      Apple           Ultrabook            Intel Core i5    8  Intel
# 1      Apple           Ultrabook            Intel Core i5    8  Intel
# 2         HP            Notebook            Intel Core i5    8  Intel
# 3      Apple           Ultrabook            Intel Core i7   16    AMD
# 4      Apple           Ultrabook            Intel Core i5    8  Intel
# ...      ...                 ...                      ...  ...    ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7    4  Intel
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7   16  Intel
# 1300  Lenovo            Notebook  Intel Celeron Dual Core    2  Intel
# 1301      HP            Notebook            Intel Core i7    6    AMD
# 1302    Asus            Notebook  Intel Celeron Dual Core    4  Intel
#
#                        OpSys  Weight        Price  IPS  Touchscreen       PPI
# 0                        Mac    1.37   71378.6832    1            0  492872.0
# 1                        Mac    1.34   47895.5232    0            0  155977.0
# 2     Chrome OS/Andriod/NoOS    1.86   30636.0000    0            0  236377.0
# 3                        Mac    1.83  135195.3360    1            0  538714.0
# 4                        Mac    1.37   96095.8080    1            0  492872.0
# ...                      ...     ...          ...  ...          ...       ...
# 1298                 Windows    1.80   33992.6400    1            1  263391.0
# 1299                 Windows    1.30   79866.7200    1            1  770060.0
# 1300                 Windows    1.50   12201.1200    0            0  133337.0
# 1301                 Windows    2.19   40705.9200    0            0  119662.0
# 1302                 Windows    2.20   19660.3200    0            0  119662.0
#
# [1302 rows x 11 columns]

# %%
sns.kdeplot(df['Price'])
#as this is not uniform ,we try taking the log of the prices
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(np.log(df['Price']))
#in this we get a graph which is increased in the center
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
x=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
x
# Out:
#      Company            TypeName                      Cpu  Ram    Gpu  \
# 0      Apple           Ultrabook            Intel Core i5    8  Intel
# 1      Apple           Ultrabook            Intel Core i5    8  Intel
# 2         HP            Notebook            Intel Core i5    8  Intel
# 3      Apple           Ultrabook            Intel Core i7   16    AMD
# 4      Apple           Ultrabook            Intel Core i5    8  Intel
# ...      ...                 ...                      ...  ...    ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7    4  Intel
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7   16  Intel
# 1300  Lenovo            Notebook  Intel Celeron Dual Core    2  Intel
# 1301      HP            Notebook            Intel Core i7    6    AMD
# 1302    Asus            Notebook  Intel Celeron Dual Core    4  Intel
#
#                        OpSys  Weight  IPS  Touchscreen       PPI
# 0                        Mac    1.37    1            0  492872.0
# 1                        Mac    1.34    0            0  155977.0
# 2     Chrome OS/Andriod/NoOS    1.86    0            0  236377.0
# 3                        Mac    1.83    1            0  538714.0
# 4                        Mac    1.37    1            0  492872.0
# ...                      ...     ...  ...          ...       ...
# 1298                 Windows    1.80    1            1  263391.0
# 1299                 Windows    1.30    1            1  770060.0
# 1300                 Windows    1.50    0            0  133337.0
# 1301                 Windows    2.19    0            0  119662.0
# 1302                 Windows    2.20    0            0  119662.0
#
# [1302 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=2)

# %%
x.shape
# Out:
# (1302, 10)

# %%
x_test.shape
#this is a random set of values
x_test
# Out:
#      Company            TypeName                      Cpu  Ram     Gpu  \
# 248       HP            Notebook            Intel Core i5    4   Intel
# 555     Asus            Notebook  Intel Celeron Dual Core    4   Intel
# 1251      HP            Notebook            AMD Processor    4     AMD
# 547   Lenovo            Notebook            Intel Core i5    4   Intel
# 885       HP  2 in 1 Convertible            Intel Core i5    4   Intel
# ...      ...                 ...                      ...  ...     ...
# 1129      HP              Gaming            Intel Core i5    8  Nvidia
# 172   Lenovo            Notebook            AMD Processor    4     AMD
# 322     Asus            Notebook            Intel Core i7    8   Intel
# 996       HP           Ultrabook            Intel Core i7    8   Intel
# 470       HP  2 in 1 Convertible            Intel Core i7    8   Intel
#
#                        OpSys  Weight  IPS  Touchscreen        PPI
# 248                  Windows    1.49    1            0   277254.0
# 555                    Linux    2.00    0            0   119662.0
# 1251                 Windows    1.86    0            0   119662.0
# 547   Chrome OS/Andriod/NoOS    2.15    0            0   236377.0
# 885                  Windows    1.28    0            1   277254.0
# ...                      ...     ...  ...          ...        ...
# 1129                 Windows    3.35    1            0   213149.0
# 172   Chrome OS/Andriod/NoOS    2.20    0            0   119662.0
# 322                  Windows    2.00    0            0   263391.0
# 996                  Windows    1.11    1            1   277254.0
# 470                  Windows    1.29    1            1  1108854.0
#
# [196 rows x 10 columns]

# %%
x_train.shape
#these are randomly choosen values
x_train
# Out:
#       Company            TypeName                      Cpu  Ram     Gpu  \
# 183   Toshiba            Notebook            Intel Core i5    8   Intel
# 1141      MSI              Gaming            Intel Core i7    8  Nvidia
# 1049     Asus             Netbook  Intel Celeron Dual Core    4   Intel
# 1020     Dell  2 in 1 Convertible            Intel Core i3    4   Intel
# 878      Dell            Notebook            Intel Core i5    4  Nvidia
# ...       ...                 ...                      ...  ...     ...
# 466      Acer            Notebook            Intel Core i3    4  Nvidia
# 299      Asus           Ultrabook            Intel Core i7   16  Nvidia
# 493      Acer            Notebook            AMD Processor    8     AMD
# 527    Lenovo            Notebook            Intel Core i3    8  Nvidia
# 1193    Apple           Ultrabook    Other Intel Processor    8   Intel
#
#                        OpSys  Weight  IPS  Touchscreen       PPI
# 183                  Windows    2.00    0            0  119662.0
# 1141                 Windows    2.40    0            0  236377.0
# 1049  Chrome OS/Andriod/NoOS    1.20    0            0  160924.0
# 1020                 Windows    2.08    1            1  236377.0
# 878                  Windows    2.18    0            0  236377.0
# ...                      ...     ...  ...          ...       ...
# 466                  Windows    2.20    0            0  119662.0
# 299                  Windows    1.63    0            0  236377.0
# 493                  Windows    2.20    0            0  119662.0
# 527   Chrome OS/Andriod/NoOS    2.20    0            0  119662.0
# 1193                     Mac    0.92    1            0  442488.0
#
# [1106 rows x 10 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
df
# Out:
#      Company            TypeName                      Cpu  Ram    Gpu  \
# 0      Apple           Ultrabook            Intel Core i5    8  Intel
# 1      Apple           Ultrabook            Intel Core i5    8  Intel
# 2         HP            Notebook            Intel Core i5    8  Intel
# 3      Apple           Ultrabook            Intel Core i7   16    AMD
# 4      Apple           Ultrabook            Intel Core i5    8  Intel
# ...      ...                 ...                      ...  ...    ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7    4  Intel
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7   16  Intel
# 1300  Lenovo            Notebook  Intel Celeron Dual Core    2  Intel
# 1301      HP            Notebook            Intel Core i7    6    AMD
# 1302    Asus            Notebook  Intel Celeron Dual Core    4  Intel
#
#                        OpSys  Weight        Price  IPS  Touchscreen       PPI
# 0                        Mac    1.37   71378.6832    1            0  492872.0
# 1                        Mac    1.34   47895.5232    0            0  155977.0
# 2     Chrome OS/Andriod/NoOS    1.86   30636.0000    0            0  236377.0
# 3                        Mac    1.83  135195.3360    1            0  538714.0
# 4                        Mac    1.37   96095.8080    1            0  492872.0
# ...                      ...     ...          ...  ...          ...       ...
# 1298                 Windows    1.80   33992.6400    1            1  263391.0
# 1299                 Windows    1.30   79866.7200    1            1  770060.0
# 1300                 Windows    1.50   12201.1200    0            0  133337.0
# 1301                 Windows    2.19   40705.9200    0            0  119662.0
# 1302                 Windows    2.20   19660.3200    0            0  119662.0
#
# [1302 rows x 11 columns]

# %%
#Linear Regression
step1 = ColumnTransformer(transformers=[('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), [0, 1, 2, 4, 5])], remainder='passthrough')
step2 = LinearRegression()
pipe = Pipeline([('step1', step1), ('step2', step2)])
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('MSE', mean_squared_error(y_test, y_pred))
# Out:
# R2 score 0.8060958879040102
# MSE 0.07417823520128128

# %%
#Ridge Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],
                        remainder='passthrough')
step2=Ridge(alpha=10)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.8133963612391667
# MAE 0.2119701515462986
# MSE 0.07138543095240679

# %%
#Lasso Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=Lasso(alpha=0.001)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.8107221180185731
# MAE 0.2137658843226582
# MSE 0.07240846569085743

# %%
#KNN Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=KNeighborsRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.843943281003832
# MAE 0.19077333008244557
# MSE 0.059699672592334996

# %%
#Regression trees
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2= DecisionTreeRegressor(max_depth=8)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.8183981642951788
# MAE 0.194940520689374
# MSE 0.06947198559269374

# %%
#Adaboost Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=AdaBoostRegressor(n_estimators=1000)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-349-00b1bdd45208> in <cell line: 3>()
#       1 #Adaboost Regression
#       2 step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
# ----> 3 step2=AdaBoostRegressor(n_estimators=1000)
#       4 pipe=Pipeline([('step1',step1),('step2',step2)])
#       5 pipe.fit(x_train,y_train)
#
# NameError: name 'AdaBoostRegressor' is not defined

# %%
#Gradient Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=GradientBoostingRegressor(n_estimators=500)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-351-775da58fe84e> in <cell line: 3>()
#       1 #Gradient Regression
#       2 step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
# ----> 3 step2=GradientBoostingRegressor(n_estimators=500)
#       4 pipe=Pipeline([('step1',step1),('step2',step2)])
#       5 pipe.fit(x_train,y_train)
#
# NameError: name 'GradientBoostingRegressor' is not defined

# %%
#Extreme Gradient Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2= XGBRegressor(n_estimators=10,max_depth=12,learning_rate=0.5)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.8622063825356795
# MAE 0.16893223211482034
# MSE 0.052713102651705646

# %%
#Support Vector Machine Regressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2= SVR(C=100)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.37032122573854387
# MAE 0.3968149615030957
# MSE 0.24088432015974146

# %%
#Random Forest Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2= RandomForestRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.8747261816411773
# MAE 0.1631724799116401
# MSE 0.04792363948518617

# %%
# !pip install streamlit==0.83.0 --quiet

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# %%writefile app.py
import streamlit as st
st.title("Laptop Price Predictor")
st.text("This app is designed to predict the laptop price based on the configuration")
st.text("Once the configuration details of the laptop are entered,")
st.text("please click on the PREDICT button to get the estimated price of the laptop")

import pickle
import numpy as np
pipe=pickle.load(open('pipe.pkl','rb'))
df=pickle.load(open('df.pkl','rb'))

company=st.selectbox("Brand",df['Company'].unique(),index=4)
type1=st.selectbox("Type",df['TypeName'].unique(),index=1)
cpu=st.selectbox("Processor",df['Cpu'].unique(),index=0)
ram=st.selectbox("RAM(in GB)",[2,4,6,8,12,16,24,32,64,128],index=3)
gpu=st.selectbox('Graphics Card',df['Gpu'].unique(),index=0)
os=st.selectbox('Operating System',df['OpSys'].unique(),index=2)
weight=st.slider('Weight(in kg)',min_value=0,max_value=4,value=2)
ips=st.selectbox('IPS Display?',['No','Yes'])
touchscreen=st.selectbox('Touchscreen?',['No','Yes'])
screen_size=st.number_input("Size of the screen(In Inches, measured diagonally)",
min_value=10,max_value=18,value=15)
resolution=st.selectbox("Screen Resolution",['1920x1080','3840x2160','3200x1800',
'2560x1600','2880x1800','1366x768','2304x1440','1440x900','2560x1440','1600x900',
'2256x1504','2400x1600'],index=0)

if st.button("PREDICT PRICE"):
  ppi=None
  if touchscreen =='Yes':
    touchscreen=1
  else:
    touchscreen=0
  if ips == 'Yes':
    ips=1
  else:
    ips=0
  X_res=int(resolution.split('x')[0])
  Y_res=int(resolution.split('x')[1])

  ppi =((X_res**2)+(Y_res**2))**0.5/screen_size

  query=np.array([[company,type1,cpu,ram,gpu,os,weight,ips,touchscreen,ppi]])
  op=np.exp(pipe.predict(query))
  st.subheader("The predicted price for the laptop with above mentioned configuration is:")
  st.subheader("Rs."+str(round(op[0])))
# Out:
# Writing app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# 2024-10-17 10:50:49.726 INFO    numexpr.utils: NumExpr defaulting to 2 threads.
# Need to install the following packages:
#   localtunnel@2.0.2
# Ok to proceed? (y)
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.19.24.178:8501
#
#   Stopping...
# ^C
